# %% [markdown]
# # LINE PROFILING

# %% [markdown]
# **Machine Specifications:**
# - Device: Dell XPS 15 9570
# - OS: UBUNTU 20.04 LTS
# - Memory: 16GiB System Memory, 2x 8GiB SODIMM DDR4 Synchronous 2667 MHz
# - Cache:  L1 cache -> 384KiB, L2 cache -> 1536KiB, L3 cache -> 9Mib
# - Swap: 20.3GiB
# - Processor: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, 6 Cores, 12 threads
# - Graphic Card: Integrated -> UHD Graphics 630 Mobile, Discrete -> GeForce GTX 1050 Ti Mobile

# %% [markdown]
# ## Importing Profilers and Lightcurve

# %%
import warnings, logging
import numpy as np
from stingray import Lightcurve, Crossspectrum, Powerspectrum

warnings.filterwarnings('ignore')
# %load_ext line_profiler

# %% [markdown]
# ## check_lightcurve

# %%
times = np.arange(100000000)
counts = np.random.rand(100000000)*100

# %lprun -f Lightcurve.check_lightcurve Lightcurve(times[::-1], counts)

del times, counts
# Out:
# WARNING:root:Checking if light curve is well behaved. This can take time, so if you are sure it is already sorted, specify skip_checks=True at light curve creation.
# WARNING:root:Checking if light curve is sorted.
# WARNING:root:The light curve is unsorted. Now, sorting...
# WARNING:root:Computing the bin time ``dt``. This can take time. If you know the bin time, please specify it at light curve creation
# Timer unit: 1e-06 s
#
# Total time: 15.6726 s
# File: /home/apollo/stingray/stingray/lightcurve.py
# Function: check_lightcurve at line 402
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    402                                               def check_lightcurve(self):
#    403                                                   """Make various checks on the lightcurve.
#    404
#    405                                                   It can be slow, use it if you are not sure about your
#    406                                                   input data.
#    407                                                   """
#    408                                                   # Issue a warning if the input time iterable isn't regularly spaced,
#    409                                                   # i.e. the bin sizes aren't equal throughout.
#    410
#    411         1         47.0     47.0      0.0          check_gtis(self.gti)
#    412
#    413         1          0.0      0.0      0.0          dt_array = []
#    414         2          8.0      4.0      0.0          for g in self.gti:
#    415         1     745345.0 745345.0      4.8              mask = create_gti_mask(self.time, [g], dt=self.dt)
#    416         1     170175.0 170175.0      1.1              t = self.time[mask]
#    417         1    3580031.0 3580031.0     22.8              dt_array.extend(np.diff(t))
#    418         1    9674389.0 9674389.0     61.7          dt_array = np.asarray(dt_array)
#    419
#    420         1    1502578.0 1502578.0      9.6          if not (np.allclose(dt_array, np.repeat(self.dt, dt_array.shape[0]))):
#    421                                                       simon("Bin sizes in input time array aren't equal throughout! "
#    422                                                             "This could cause problems with Fourier transforms. "
#    423                                                             "Please make the input time evenly sampled.")

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## counts_err

# %%
def poisson_symmetrical_errors(counts):
    from astropy.stats import poisson_conf_interval
    counts_int = np.asarray(counts, dtype=np.int64)
    count_values = np.unique(counts_int)
    err_low, err_high = \
        poisson_conf_interval(count_values,
                              interval='frequentist-confidence', sigma=1)
    # calculate approximately symmetric uncertainties
    err_low -= np.asarray(count_values)
    err_high -= np.asarray(count_values)
    err = (np.absolute(err_low) + np.absolute(err_high)) / 2.0

    idxs = np.searchsorted(count_values, counts_int)
    return err[idxs]

# %%
def counts_err(Lightcurve):
        counts_err = Lightcurve._counts_err
        if counts_err is None and Lightcurve._countrate_err is not None:
            counts_err = Lightcurve._countrate_err * Lightcurve.dt
        elif counts_err is None:
            if Lightcurve.err_dist.lower() == 'poisson':
                counts_err = poisson_symmetrical_errors(Lightcurve.counts)
            else:
                counts_err = np.zeros_like(Lightcurve.counts)

        # If not in low-memory regime, cache the values ONLY if they have
        # been changed!
        if Lightcurve._counts_err is not counts_err:
            if not Lightcurve.low_memory or Lightcurve.input_counts:
                Lightcurve._counts_err = counts_err

        return counts_err

# %%
times = np.arange(100000000)
counts = np.random.rand(100000000)*100

lc = Lightcurve(times, counts, dt=1.0, skip_checks=True)

# %lprun -f poisson_symmetrical_errors -f counts_err counts_err(lc)

del times, counts, lc1
# Out:
# Timer unit: 1e-06 s
#
# Total time: 7.67516 s
# File: <ipython-input-3-d7c5d8acecc9>
# Function: poisson_symmetrical_errors at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def poisson_symmetrical_errors(counts):
#      2         1      14215.0  14215.0      0.2      from astropy.stats import poisson_conf_interval
#      3         1     122985.0 122985.0      1.6      counts_int = np.asarray(counts, dtype=np.int64)
#      4         1    3625005.0 3625005.0     47.2      count_values = np.unique(counts_int)
#      5         1          7.0      7.0      0.0      err_low, err_high = \
#      6         2       3167.0   1583.5      0.0          poisson_conf_interval(count_values,
#      7         1          1.0      1.0      0.0                                interval='frequentist-confidence', sigma=1)
#      8                                               # calculate approximately symmetric uncertainties
#      9         1          7.0      7.0      0.0      err_low -= np.asarray(count_values)
#     10         1          3.0      3.0      0.0      err_high -= np.asarray(count_values)
#     11         1          5.0      5.0      0.0      err = (np.absolute(err_low) + np.absolute(err_high)) / 2.0
#     12
#     13         1    3717191.0 3717191.0     48.4      idxs = np.searchsorted(count_values, counts_int)
#     14         1     192574.0 192574.0      2.5      return err[idxs]
#
# Total time: 7.67767 s
# File: <ipython-input-4-84320ad29132>
# Function: counts_err at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def counts_err(Lightcurve):
#      2         1          1.0      1.0      0.0          counts_err = Lightcurve._counts_err
#      3         1          1.0      1.0      0.0          if counts_err is None and Lightcurve._countrate_err is not None:
#      4                                                       counts_err = Lightcurve._countrate_err * Lightcurve.dt
#      5         1          0.0      0.0      0.0          elif counts_err is None:
#      6         1          1.0      1.0      0.0              if Lightcurve.err_dist.lower() == 'poisson':
#      7         1    7677661.0 7677661.0    100.0                  counts_err = poisson_symmetrical_errors(Lightcurve.counts)
#      8                                                       else:
#      9                                                           counts_err = np.zeros_like(Lightcurve.counts)
#     10
#     11                                                   # If not in low-memory regime, cache the values ONLY if they have
#     12                                                   # been changed!
#     13         1          3.0      3.0      0.0          if Lightcurve._counts_err is not counts_err:
#     14         1          1.0      1.0      0.0              if not Lightcurve.low_memory or Lightcurve.input_counts:
#     15         1          1.0      1.0      0.0                  Lightcurve._counts_err = counts_err
#     16
#     17         1          0.0      0.0      0.0          return counts_err

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## cross_two_gtis

# %%
def join_equal_gti_boundaries(gti):
    new_gtis=[]
    for l in gti:
        new_gtis.append(l)
    touching = gti[:-1, 1] == gti[1:, 0]
    ng = []
    count = 0
    while count < len(gti)-1:
        if touching[count]:
            new_gtis[count+1] = [new_gtis[count][0], new_gtis[count+1][1]]
        else:
            ng.append(new_gtis[count])
        count += 1
    ng.append(new_gtis[-1])
    return np.asarray(ng)

# %%
def check_gtis(gti):
    gti = np.asarray(gti)
    if len(gti) < 1:
        raise ValueError("Empty GTIs")

    if len(gti) != gti.shape[0] or len(gti.shape) != 2 or \
            len(gti) != gti.shape[0]:
        raise TypeError("Please check formatting of GTIs. They need to be"
                        " provided as [[gti00, gti01], [gti10, gti11], ...]")

    gti_start = gti[:, 0]
    gti_end = gti[:, 1]

    # Check that GTIs are well-behaved
    if not np.all(gti_end >= gti_start):
        raise ValueError('This GTI end times must be larger than '
                         'GTI start times')

    # Check that there are no overlaps in GTIs
    if not np.all(gti_start[1:] >= gti_end[:-1]):
        raise ValueError('This GTI has overlaps')

    return

# %%
def cross_two_gtis(gti0, gti1):

    gti0 = join_equal_gti_boundaries(np.asarray(gti0))
    gti1 = join_equal_gti_boundaries(np.asarray(gti1))
    # Check GTIs
    check_gtis(gti0)
    check_gtis(gti1)

    gti0_start = gti0[:, 0]
    gti0_end = gti0[:, 1]
    gti1_start = gti1[:, 0]
    gti1_end = gti1[:, 1]

    # Create a list that references to the two start and end series
    gti_start = [gti0_start, gti1_start]
    gti_end = [gti0_end, gti1_end]

    # Concatenate the series, while keeping track of the correct origin of
    # each start and end time
    gti0_tag = np.array([0 for g in gti0_start], dtype=bool)
    gti1_tag = np.array([1 for g in gti1_start], dtype=bool)
    conc_start = np.concatenate((gti0_start, gti1_start))
    conc_end = np.concatenate((gti0_end, gti1_end))
    conc_tag = np.concatenate((gti0_tag, gti1_tag))

    # Put in time order
    order = np.argsort(conc_end)
    conc_start = conc_start[order]
    conc_end = conc_end[order]
    conc_tag = conc_tag[order]

    last_end = conc_start[0] - 1
    final_gti = []
    for ie, e in enumerate(conc_end):
        # Is this ending in series 0 or 1?
        this_series = int(conc_tag[ie])
        other_series = int(this_series == 0)

        # Check that this closes intervals in both series.
        # 1. Check that there is an opening in both series 0 and 1 lower than e
        try:
            st_pos = \
                np.argmax(gti_start[this_series][gti_start[this_series] < e])
            so_pos = \
                np.argmax(gti_start[other_series][gti_start[other_series] < e])
            st = gti_start[this_series][st_pos]
            so = gti_start[other_series][so_pos]

            s = np.max([st, so])
        except:  # pragma: no cover
            continue

        # If this start is inside the last interval (It can happen for equal
        # GTI start times between the two series), then skip!
        if s <= last_end:
            continue
        # 2. Check that there is no closing before e in the "other series",
        # from intervals starting either after s, or starting and ending
        # between the last closed interval and this one
        cond1 = (gti_end[other_series] > s) * (gti_end[other_series] < e)
        cond2 = gti_end[other_series][so_pos] < s
        condition = np.any(np.logical_or(cond1, cond2))
        # Well, if none of the conditions at point 2 apply, then you can
        # create the new gti!
        if not condition:
            final_gti.append([s, e])
            last_end = e

    return np.array(final_gti)

# %%
def split(Lightcurve, min_gap, min_points=1):
        # calculate the difference between time bins
        tdiff = np.diff(Lightcurve.time)
        # find all distances between time bins that are larger than `min_gap`
        gap_idx = np.where(tdiff >= min_gap)[0]

        # tolerance for the newly created GTIs: Note that this seems to work
        # with a tolerance of 2, but not if I substitute 10. I don't know why
        epsilon = np.min(tdiff)/2.0

        # calculate new GTIs
        gti_start = np.hstack([Lightcurve.time[0]-epsilon, Lightcurve.time[gap_idx+1]-epsilon])
        gti_stop = np.hstack([Lightcurve.time[gap_idx]+epsilon, Lightcurve.time[-1]+epsilon])

        gti = np.vstack([gti_start, gti_stop]).T
        if hasattr(Lightcurve, 'gti') and Lightcurve.gti is not None:
            gti = cross_two_gtis(Lightcurve.gti, gti)
        Lightcurve.gti = gti

        lc_split = Lightcurve.split_by_gti(min_points=min_points)
        return lc_split

# %%
times = np.arange(0, 100000000, np.random.randint(4, 9))
counts = np.random.rand(len(times))*100
    
lc = Lightcurve(times, counts, dt=1.0, skip_checks=True)

# %lprun -f split -f cross_two_gtis -f join_equal_gti_boundaries -f check_gtis split(lc, 4)

del times, counts, lc
# Out:
# Timer unit: 1e-06 s
#
# Total time: 45.0078 s
# File: <ipython-input-2-5bc0ee67f626>
# Function: join_equal_gti_boundaries at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def join_equal_gti_boundaries(gti):
#      2         2          2.0      1.0      0.0      new_gtis=[]
#      3  16666670    5804738.0      0.3     12.9      for l in gti:
#      4  16666668    4826325.0      0.3     10.7          new_gtis.append(l)
#      5         2      13926.0   6963.0      0.0      touching = gti[:-1, 1] == gti[1:, 0]
#      6         2          2.0      1.0      0.0      ng = []
#      7         2          0.0      0.0      0.0      count = 0
#      8  16666668    6064718.0      0.4     13.5      while count < len(gti)-1:
#      9  16666666    5445759.0      0.3     12.1          if touching[count]:
#     10  16666666   17908796.0      1.1     39.8              new_gtis[count+1] = [new_gtis[count][0], new_gtis[count+1][1]]
#     11                                                   else:
#     12                                                       ng.append(new_gtis[count])
#     13  16666666    4943533.0      0.3     11.0          count += 1
#     14         2          2.0      1.0      0.0      ng.append(new_gtis[-1])
#     15         2         40.0     20.0      0.0      return np.asarray(ng)
#
# Total time: 9.3e-05 s
# File: <ipython-input-3-38e0b0b669bc>
# Function: check_gtis at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def check_gtis(gti):
#      2         2          9.0      4.5      9.7      gti = np.asarray(gti)
#      3         2          1.0      0.5      1.1      if len(gti) < 1:
#      4                                                   raise ValueError("Empty GTIs")
#      5
#      6         4          4.0      1.0      4.3      if len(gti) != gti.shape[0] or len(gti.shape) != 2 or \
#      7         2          1.0      0.5      1.1              len(gti) != gti.shape[0]:
#      8                                                   raise TypeError("Please check formatting of GTIs. They need to be"
#      9                                                                   " provided as [[gti00, gti01], [gti10, gti11], ...]")
#     10
#     11         2          5.0      2.5      5.4      gti_start = gti[:, 0]
#     12         2          1.0      0.5      1.1      gti_end = gti[:, 1]
#     13
#     14                                               # Check that GTIs are well-behaved
#     15         2         50.0     25.0     53.8      if not np.all(gti_end >= gti_start):
#     16                                                   raise ValueError('This GTI end times must be larger than '
#     17                                                                    'GTI start times')
#     18
#     19                                               # Check that there are no overlaps in GTIs
#     20         2         20.0     10.0     21.5      if not np.all(gti_start[1:] >= gti_end[:-1]):
#     21                                                   raise ValueError('This GTI has overlaps')
#     22
#     23         2          2.0      1.0      2.2      return
#
# Total time: 70.3027 s
# File: <ipython-input-4-878f24f8dd37>
# Function: cross_two_gtis at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def cross_two_gtis(gti0, gti1):
#      2
#      3         1         28.0     28.0      0.0      gti0 = join_equal_gti_boundaries(np.asarray(gti0))
#      4         1   70302321.0 70302321.0    100.0      gti1 = join_equal_gti_boundaries(np.asarray(gti1))
#      5                                               # Check GTIs
#      6         1         98.0     98.0      0.0      check_gtis(gti0)
#      7         1         26.0     26.0      0.0      check_gtis(gti1)
#      8
#      9         1          1.0      1.0      0.0      gti0_start = gti0[:, 0]
#     10         1          1.0      1.0      0.0      gti0_end = gti0[:, 1]
#     11         1          0.0      0.0      0.0      gti1_start = gti1[:, 0]
#     12         1          1.0      1.0      0.0      gti1_end = gti1[:, 1]
#     13
#     14                                               # Create a list that references to the two start and end series
#     15         1          1.0      1.0      0.0      gti_start = [gti0_start, gti1_start]
#     16         1          0.0      0.0      0.0      gti_end = [gti0_end, gti1_end]
#     17
#     18                                               # Concatenate the series, while keeping track of the correct origin of
#     19                                               # each start and end time
#     20         1         18.0     18.0      0.0      gti0_tag = np.array([0 for g in gti0_start], dtype=bool)
#     21         1          5.0      5.0      0.0      gti1_tag = np.array([1 for g in gti1_start], dtype=bool)
#     22         1          8.0      8.0      0.0      conc_start = np.concatenate((gti0_start, gti1_start))
#     23         1          3.0      3.0      0.0      conc_end = np.concatenate((gti0_end, gti1_end))
#     24         1          3.0      3.0      0.0      conc_tag = np.concatenate((gti0_tag, gti1_tag))
#     25
#     26                                               # Put in time order
#     27         1         74.0     74.0      0.0      order = np.argsort(conc_end)
#     28         1          2.0      2.0      0.0      conc_start = conc_start[order]
#     29         1          1.0      1.0      0.0      conc_end = conc_end[order]
#     30         1          1.0      1.0      0.0      conc_tag = conc_tag[order]
#     31
#     32         1          3.0      3.0      0.0      last_end = conc_start[0] - 1
#     33         1          0.0      0.0      0.0      final_gti = []
#     34         3          6.0      2.0      0.0      for ie, e in enumerate(conc_end):
#     35                                                   # Is this ending in series 0 or 1?
#     36         2          4.0      2.0      0.0          this_series = int(conc_tag[ie])
#     37         2          2.0      1.0      0.0          other_series = int(this_series == 0)
#     38
#     39                                                   # Check that this closes intervals in both series.
#     40                                                   # 1. Check that there is an opening in both series 0 and 1 lower than e
#     41         2          2.0      1.0      0.0          try:
#     42         2          2.0      1.0      0.0              st_pos = \
#     43         2         27.0     13.5      0.0                  np.argmax(gti_start[this_series][gti_start[this_series] < e])
#     44         2          2.0      1.0      0.0              so_pos = \
#     45         2         13.0      6.5      0.0                  np.argmax(gti_start[other_series][gti_start[other_series] < e])
#     46         2          2.0      1.0      0.0              st = gti_start[this_series][st_pos]
#     47         2          1.0      0.5      0.0              so = gti_start[other_series][so_pos]
#     48
#     49         2         40.0     20.0      0.0              s = np.max([st, so])
#     50                                                   except:  # pragma: no cover
#     51                                                       continue
#     52
#     53                                                   # If this start is inside the last interval (It can happen for equal
#     54                                                   # GTI start times between the two series), then skip!
#     55         2          2.0      1.0      0.0          if s <= last_end:
#     56         1          0.0      0.0      0.0              continue
#     57                                                   # 2. Check that there is no closing before e in the "other series",
#     58                                                   # from intervals starting either after s, or starting and ending
#     59                                                   # between the last closed interval and this one
#     60         1          7.0      7.0      0.0          cond1 = (gti_end[other_series] > s) * (gti_end[other_series] < e)
#     61         1          1.0      1.0      0.0          cond2 = gti_end[other_series][so_pos] < s
#     62         1         13.0     13.0      0.0          condition = np.any(np.logical_or(cond1, cond2))
#     63                                                   # Well, if none of the conditions at point 2 apply, then you can
#     64                                                   # create the new gti!
#     65         1          1.0      1.0      0.0          if not condition:
#     66         1          1.0      1.0      0.0              final_gti.append([s, e])
#     67         1          0.0      0.0      0.0              last_end = e
#     68
#     69         1          3.0      3.0      0.0      return np.array(final_gti)
#
# Total time: 72.0765 s
# File: <ipython-input-5-cefd0a21f679>
# Function: split at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def split(Lightcurve, min_gap, min_points=1):
#      2                                                   # calculate the difference between time bins
#      3         1      18519.0  18519.0      0.0          tdiff = np.diff(Lightcurve.time)
#      4                                                   # find all distances between time bins that are larger than `min_gap`
#      5         1      28650.0  28650.0      0.0          gap_idx = np.where(tdiff >= min_gap)[0]
#      6
#      7                                                   # tolerance for the newly created GTIs: Note that this seems to work
#      8                                                   # with a tolerance of 2, but not if I substitute 10. I don't know why
#      9         1      10753.0  10753.0      0.0          epsilon = np.min(tdiff)/2.0
#     10
#     11                                                   # calculate new GTIs
#     12         1      92907.0  92907.0      0.1          gti_start = np.hstack([Lightcurve.time[0]-epsilon, Lightcurve.time[gap_idx+1]-epsilon])
#     13         1      77324.0  77324.0      0.1          gti_stop = np.hstack([Lightcurve.time[gap_idx]+epsilon, Lightcurve.time[-1]+epsilon])
#     14
#     15         1      40033.0  40033.0      0.1          gti = np.vstack([gti_start, gti_stop]).T
#     16         1         20.0     20.0      0.0          if hasattr(Lightcurve, 'gti') and Lightcurve.gti is not None:
#     17         1   70303404.0 70303404.0     97.5              gti = cross_two_gtis(Lightcurve.gti, gti)
#     18         1          7.0      7.0      0.0          Lightcurve.gti = gti
#     19
#     20         1    1504877.0 1504877.0      2.1          lc_split = Lightcurve.split_by_gti(min_points=min_points)
#     21         1          1.0      1.0      0.0          return lc_split

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## counts

# %%
def countFunc(Lightcurve):
    counts = Lightcurve._counts
    if Lightcurve._counts is None:
        counts = Lightcurve._countrate * Lightcurve.dt
        # If not in low-memory regime, cache the values
        if not Lightcurve.low_memory or Lightcurve.input_counts:
            Lightcurve._counts = counts

    return counts

# %%
times = np.arange(100000000)
counts = np.random.rand(100000000)*100

lc = Lightcurve(times, counts, dt=1.0, skip_checks=True)

# %lprun -f countFunc countFunc(lc)

del times, counts, lc
# Out:
# Timer unit: 1e-06 s
#
# Total time: 2e-06 s
# File: <ipython-input-8-8139c4bf5cf9>
# Function: countFunc at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def countFunc(Lightcurve):
#      2         1          2.0      2.0    100.0      counts = Lightcurve._counts
#      3         1          0.0      0.0      0.0      if Lightcurve._counts is None:
#      4                                                   counts = Lightcurve._countrate * Lightcurve.dt
#      5                                                   # If not in low-memory regime, cache the values
#      6                                                   if not Lightcurve.low_memory or Lightcurve.input_counts:
#      7                                                       Lightcurve._counts = counts
#      8
#      9         1          0.0      0.0      0.0      return counts

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## _ getitem _

# %%
times = np.arange(100000000)
counts = np.random.rand(100000000)*100

lc = Lightcurve(times, counts, dt=1.0, skip_checks=True)

# %lprun -f lc.__getitem__ lc.__getitem__(slice(10000, 10000000))

del times, counts, lc
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.000308 s
# File: /home/apollo/stingray/stingray/lightcurve.py
# Function: __getitem__ at line 628
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    628                                               def __getitem__(self, index):
#    629                                                   """
#    630                                                   Return the corresponding count value at the index or a new :class:`Lightcurve`
#    631                                                   object upon slicing.
#    632
#    633                                                   This method adds functionality to retrieve the count value at
#    634                                                   a particular index. This also can be used for slicing and generating
#    635                                                   a new :class:`Lightcurve` object. GTIs are recalculated based on the new light
#    636                                                   curve segment
#    637
#    638                                                   If the slice object is of kind ``start:stop:step``, GTIs are also sliced,
#    639                                                   and rewritten as ``zip(time - self.dt /2, time + self.dt / 2)``
#    640
#    641                                                   Parameters
#    642                                                   ----------
#    643                                                   index : int or slice instance
#    644                                                       Index value of the time array or a slice object.
#    645
#    646                                                   Examples
#    647                                                   --------
#    648                                                   >>> time = [1, 2, 3, 4, 5, 6, 7, 8, 9]
#    649                                                   >>> count = [11, 22, 33, 44, 55, 66, 77, 88, 99]
#    650                                                   >>> lc = Lightcurve(time, count, dt=1)
#    651                                                   >>> lc[2]
#    652                                                   33
#    653                                                   >>> lc[:2].counts
#    654                                                   array([11, 22])
#    655                                                   """
#    656         1          3.0      3.0      1.0          if isinstance(index, (int, np.integer)):
#    657                                                       return self.counts[index]
#    658         1          1.0      1.0      0.3          elif isinstance(index, slice):
#    659         1          2.0      2.0      0.6              start = assign_value_if_none(index.start, 0)
#    660         1          3.0      3.0      1.0              stop = assign_value_if_none(index.stop, len(self.counts))
#    661         1          1.0      1.0      0.3              step = assign_value_if_none(index.step, 1)
#    662
#    663         1          2.0      2.0      0.6              new_counts = self.counts[start:stop:step]
#    664         1          2.0      2.0      0.6              new_time = self.time[start:stop:step]
#    665
#    666         2         10.0      5.0      3.2              new_gti = [[self.time[start] - 0.5 * self.dt,
#    667         1          4.0      4.0      1.3                          self.time[stop - 1] + 0.5 * self.dt]]
#    668         1         11.0     11.0      3.6              new_gti = np.asarray(new_gti)
#    669         1          1.0      1.0      0.3              if step > 1:
#    670                                                           new_gt1 = np.array(list(zip(new_time - self.dt / 2,
#    671                                                                                       new_time + self.dt / 2)))
#    672                                                           new_gti = cross_two_gtis(new_gti, new_gt1)
#    673         1        237.0    237.0     76.9              new_gti = cross_two_gtis(self.gti, new_gti)
#    674
#    675         2         30.0     15.0      9.7              return Lightcurve(new_time, new_counts, mjdref=self.mjdref,
#    676         1          1.0      1.0      0.3                                gti=new_gti, dt=self.dt, skip_checks=True)
#    677                                                   else:
#    678                                                       raise IndexError("The index must be either an integer or a slice "
#    679                                                                        "object !")

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## sort_counts

# %%
times = np.arange(10000000)
counts = np.random.rand(10000000)*100

lc = Lightcurve(times, counts[::-1], dt=1.0, skip_checks=True)

# %lprun -f lc.sort_counts lc.sort_counts()

del times, counts, lc
# Out:
# Timer unit: 1e-06 s
#
# Total time: 43.0702 s
# File: /home/apollo/stingray/stingray/lightcurve.py
# Function: sort_counts at line 1210
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1210                                               def sort_counts(self, reverse=False):
#   1211                                                   """
#   1212                                                   Sort a :class:`Lightcurve` object in accordance with its counts array.
#   1213
#   1214                                                   A :class:`Lightcurve` can be sorted in either increasing or decreasing order
#   1215                                                   using this method. The counts array gets sorted and the time array is
#   1216                                                   changed accordingly.
#   1217
#   1218                                                   Parameters
#   1219                                                   ----------
#   1220                                                   reverse : boolean, default ``False``
#   1221                                                       If ``True`` then the object is sorted in reverse order.
#   1222
#   1223                                                   Returns
#   1224                                                   -------
#   1225                                                   lc_new: :class:`Lightcurve` object
#   1226                                                       The :class:`Lightcurve` object with sorted ``time`` and ``counts``
#   1227                                                       arrays.
#   1228
#   1229                                                   Examples
#   1230                                                   --------
#   1231                                                   >>> time = [1, 2, 3]
#   1232                                                   >>> count = [200, 100, 300]
#   1233                                                   >>> lc = Lightcurve(time, count, dt=1)
#   1234                                                   >>> lc_new = lc.sort_counts()
#   1235                                                   >>> lc_new.time
#   1236                                                   array([2, 1, 3])
#   1237                                                   >>> lc_new.counts
#   1238                                                   array([100, 200, 300])
#   1239                                                   """
#   1240
#   1241         1    7247416.0 7247416.0     16.8          new_counts, new_time, new_counts_err = \
#   1242         2   29117694.0 14558847.0     67.6              zip(*sorted(zip(self.counts, self.time, self.counts_err),
#   1243         1          1.0      1.0      0.0                          reverse=reverse))
#   1244
#   1245         2    6705106.0 3352553.0     15.6          new_lc = Lightcurve(new_time, new_counts, err=new_counts_err,
#   1246         1         29.0     29.0      0.0                              gti=self.gti, dt=self.dt, mjdref=self.mjdref,
#   1247         1          0.0      0.0      0.0                              skip_checks=True)
#   1248
#   1249         1          2.0      2.0      0.0          return new_lc

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## join

# %%
times = np.arange(10000000)
counts = np.random.rand(10000000)*100

lc1 = Lightcurve(times, counts, dt=1.0, skip_checks=True)
lc2 = Lightcurve(times, counts[::-1], dt=1.0, skip_checks=True)

# %lprun -f lc1.join lc1.join(lc2)

del times, counts, lc1, lc2
# Out:
# Timer unit: 1e-06 s
#
# Total time: 149.834 s
# File: /home/apollo/stingray/stingray/lightcurve.py
# Function: join at line 891
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    891                                               def join(self, other):
#    892                                                   """
#    893                                                   Join two lightcurves into a single object.
#    894
#    895                                                   The new :class:`Lightcurve` object will contain time stamps from both the
#    896                                                   objects. The ``counts`` and ``countrate`` attributes in the resulting object
#    897                                                   will contain the union of the non-overlapping parts of the two individual objects,
#    898                                                   or the average in case of overlapping ``time`` arrays of both :class:`Lightcurve` objects.
#    899
#    900                                                   Good Time Intervals are also joined.
#    901
#    902                                                   Note : Ideally, the ``time`` array of both lightcurves should not overlap.
#    903
#    904                                                   Parameters
#    905                                                   ----------
#    906                                                   other : :class:`Lightcurve` object
#    907                                                       The other :class:`Lightcurve` object which is supposed to be joined with.
#    908
#    909                                                   Returns
#    910                                                   -------
#    911                                                   lc_new : :class:`Lightcurve` object
#    912                                                       The resulting :class:`Lightcurve` object.
#    913
#    914                                                   Examples
#    915                                                   --------
#    916                                                   >>> time1 = [5, 10, 15]
#    917                                                   >>> count1 = [300, 100, 400]
#    918                                                   >>> time2 = [20, 25, 30]
#    919                                                   >>> count2 = [600, 1200, 800]
#    920                                                   >>> lc1 = Lightcurve(time1, count1, dt=5)
#    921                                                   >>> lc2 = Lightcurve(time2, count2, dt=5)
#    922                                                   >>> lc = lc1.join(lc2)
#    923                                                   >>> lc.time
#    924                                                   array([ 5, 10, 15, 20, 25, 30])
#    925                                                   >>> lc.counts
#    926                                                   array([ 300,  100,  400,  600, 1200,  800])
#    927                                                   """
#    928         1          2.0      2.0      0.0          if self.mjdref != other.mjdref:
#    929                                                       raise ValueError("MJDref is different in the two light curves")
#    930
#    931         1          1.0      1.0      0.0          if self.dt != other.dt:
#    932                                                       utils.simon("The two light curves have different bin widths.")
#    933
#    934         1          1.0      1.0      0.0          if(self.tstart < other.tstart):
#    935                                                       first_lc = self
#    936                                                       second_lc = other
#    937                                                   else:
#    938         1          0.0      0.0      0.0              first_lc = other
#    939         1          1.0      1.0      0.0              second_lc = self
#    940
#    941         1    2049454.0 2049454.0      1.4          if len(np.intersect1d(self.time, other.time) > 0):
#    942
#    943         1         18.0     18.0      0.0              utils.simon("The two light curves have overlapping time ranges. "
#    944                                                                   "In the common time range, the resulting count will "
#    945                                                                   "be the average of the counts in the two light "
#    946                                                                   "curves. If you wish to sum, use `lc_sum = lc1 + "
#    947                                                                   "lc2`.")
#    948         1          1.0      1.0      0.0              valid_err = False
#    949
#    950         1          3.0      3.0      0.0              if self.err_dist.lower() != other.err_dist.lower():
#    951                                                           simon("Lightcurves have different statistics!"
#    952                                                                 "We are setting the errors to zero.")
#    953
#    954         1          1.0      1.0      0.0              elif self.err_dist.lower() in valid_statistics:
#    955         1          0.0      0.0      0.0                  valid_err = True
#    956                                                       # More conditions can be implemented for other statistics
#    957                                                       else:
#    958                                                           raise StingrayError("Statistics not recognized."
#    959                                                                               " Please use one of these: "
#    960                                                                               "{}".format(valid_statistics))
#    961
#    962         1          9.0      9.0      0.0              from collections import Counter
#    963         1         13.0     13.0      0.0              counts = Counter()
#    964         1          2.0      2.0      0.0              counts_err = Counter()
#    965
#    966  10000001    6497893.0      0.6      4.3              for i, time in enumerate(first_lc.time):
#    967  10000000   12132650.0      1.2      8.1                  counts[time] = first_lc.counts[i]
#    968  10000000   16108712.0      1.6     10.8                  counts_err[time] = first_lc.counts_err[i]
#    969
#    970  10000001    7489198.0      0.7      5.0              for i, time in enumerate(second_lc.time):
#    971
#    972  10000000    7350394.0      0.7      4.9                  if counts.get(time) is not None:  # Common time
#    973  10000000   19630891.0      2.0     13.1                      counts[time] = (counts[time] + second_lc.counts[i]) / 2
#    974  10000000    9089111.0      0.9      6.1                      counts_err[time] = \
#    975  30000000   39407071.0      1.3     26.3                          np.sqrt(((counts_err[time] ** 2) +
#    976  20000000   24733495.0      1.2     16.5                                   (second_lc.counts_err[i] ** 2)) / 2)
#    977
#    978                                                           else:
#    979                                                               counts[time] = second_lc.counts[i]
#    980                                                               counts_err[time] = second_lc.counts_err[i]
#    981
#    982         1     139680.0 139680.0      0.1              new_time = list(counts.keys())
#    983         1     133765.0 133765.0      0.1              new_counts = list(counts.values())
#    984         1          2.0      2.0      0.0              if(valid_err):
#    985         1     131873.0 131873.0      0.1                  new_counts_err = list(counts_err.values())
#    986                                                       else:
#    987                                                           new_counts_err = np.zeros_like(new_counts)
#    988
#    989         1     182652.0 182652.0      0.1              del[counts, counts_err]
#    990
#    991                                                   else:
#    992
#    993                                                       new_time = np.concatenate([first_lc.time, second_lc.time])
#    994                                                       new_counts = np.concatenate([first_lc.counts, second_lc.counts])
#    995                                                       new_counts_err = \
#    996                                                           np.concatenate([first_lc.counts_err, second_lc.counts_err])
#    997
#    998         1    1173769.0 1173769.0      0.8          new_time = np.asarray(new_time)
#    999         1    1193218.0 1193218.0      0.8          new_counts = np.asarray(new_counts)
#   1000         1    1440483.0 1440483.0      1.0          new_counts_err = np.asarray(new_counts_err)
#   1001         1     950005.0 950005.0      0.6          gti = join_gtis(self.gti, other.gti)
#   1002
#   1003         2         39.0     19.5      0.0          lc_new = Lightcurve(new_time, new_counts, err=new_counts_err, gti=gti,
#   1004         1          2.0      2.0      0.0                              mjdref=self.mjdref, dt=self.dt, skip_checks=self.skip_checks)
#   1005
#   1006         1          0.0      0.0      0.0          return lc_new

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## _fourier_cross

# %%
times = np.arange(10000000)
counts = np.random.rand(10000000)*100

lc1 = Lightcurve(times, counts, dt=1.0, skip_checks=True)
lc2 = Lightcurve(times, counts[::-1], dt=1.0, skip_checks=True)

cspec = Crossspectrum(lc1, lc2)

# %lprun -f cspec._fourier_cross cspec._fourier_cross(lc1, lc2)

del times, counts, lc1, lc2, cspec
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.612443 s
# File: /home/apollo/stingray/stingray/crossspectrum.py
# Function: _fourier_cross at line 561
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    561                                               def _fourier_cross(self, lc1, lc2):
#    562                                                   """
#    563                                                   Fourier transform the two light curves, then compute the cross spectrum.
#    564                                                   Computed as CS = lc1 x lc2* (where lc2 is the one that gets
#    565                                                   complex-conjugated)
#    566
#    567                                                   Parameters
#    568                                                   ----------
#    569                                                   lc1: :class:`stingray.Lightcurve` object
#    570                                                       One light curve to be Fourier transformed. Ths is the band of
#    571                                                       interest or channel of interest.
#    572
#    573                                                   lc2: :class:`stingray.Lightcurve` object
#    574                                                       Another light curve to be Fourier transformed.
#    575                                                       This is the reference band.
#    576
#    577                                                   Returns
#    578                                                   -------
#    579                                                   fr: numpy.ndarray
#    580                                                       The squared absolute value of the Fourier amplitudes
#    581
#    582                                                   """
#    583         1     245790.0 245790.0     40.1          fourier_1 = fft(lc1.counts)  # do Fourier transform 1
#    584         1     245054.0 245054.0     40.0          fourier_2 = fft(lc2.counts)  # do Fourier transform 2
#    585
#    586         1      38735.0  38735.0      6.3          freqs = fftfreq(lc1.n, lc1.dt)
#    587         1      68821.0  68821.0     11.2          cross = np.multiply(fourier_1[freqs > 0], np.conj(fourier_2[freqs > 0]))
#    588
#    589         1      14043.0  14043.0      2.3          return freqs[freqs > 0], cross

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## rebin_data

# %%
def apply_function_if_none(variable, value, func):
    if variable is None:
        return func(value)
    else:
        return variable

# %%
def rebin_data(x, y, dx_new, yerr=None, method='sum', dx=None):
    y = np.asarray(y)
    yerr = np.asarray(apply_function_if_none(yerr, y, np.zeros_like))

    dx_old = apply_function_if_none(dx, np.diff(x), np.median)

    if dx_new < dx_old:
        raise ValueError("New frequency resolution must be larger than "
                         "old frequency resolution.")

    step_size = dx_new / dx_old

    output = []
    outputerr = []
    for i in np.arange(0, y.shape[0], step_size):
        total = 0
        totalerr = 0

        int_i = int(i)
        prev_frac = int_i + 1 - i
        prev_bin = int_i
        total += prev_frac * y[prev_bin]
        totalerr += prev_frac * (yerr[prev_bin] ** 2)

        if i + step_size < len(x):
            # Fractional part of next bin:
            next_frac = i + step_size - int(i + step_size)
            next_bin = int(i + step_size)
            total += next_frac * y[next_bin]
            totalerr += next_frac * (yerr[next_bin] ** 2)

        total += sum(y[int(i + 1):int(i + step_size)])
        totalerr += sum(yerr[int(i + 1):int(step_size)] ** 2)
        output.append(total)
        outputerr.append(np.sqrt(totalerr))

    output = np.asarray(output)
    outputerr = np.asarray(outputerr)

    if method in ['mean', 'avg', 'average', 'arithmetic mean']:
        ybin = output / np.float(step_size)
        ybinerr = outputerr / np.sqrt(np.float(step_size))

    elif method == "sum":
        ybin = output
        ybinerr = outputerr

    else:
        raise ValueError("Method for summing or averaging not recognized. "
                         "Please enter either 'sum' or 'mean'.")

    tseg = x[-1] - x[0] + dx_old

    if (tseg / dx_new % 1) > 0:
        ybin = ybin[:-1]
        ybinerr = ybinerr[:-1]

    new_x0 = (x[0] - (0.5 * dx_old)) + (0.5 * dx_new)
    xbin = np.arange(ybin.shape[0]) * dx_new + new_x0

    return xbin, ybin, ybinerr, step_size

# %%
 def rebin(cspec, df=None, f=None, method="mean"):
        if f is None and df is None:
            raise ValueError('You need to specify at least one between f and '
                             'df')
        elif f is not None:
            df = f * cspec.df

        # rebin cross spectrum to new resolution
        binfreq, bincs, binerr, step_size = \
            rebin_data(cspec.freq, cspec.power, df, cspec.power_err,
                       method=method, dx=cspec.df)

        # make an empty cross spectrum object
        # note: syntax deliberate to work with subclass Powerspectrum
        bin_cs = copy.copy(cspec)

        # store the binned periodogram in the new object
        bin_cs.freq = binfreq
        bin_cs.power = bincs
        bin_cs.df = df
        bin_cs.n = cspec.n
        bin_cs.norm = cspec.norm
        bin_cs.nphots1 = cspec.nphots1
        bin_cs.power_err = binerr

        if hasattr(cspec, 'unnorm_power'):
            _, binpower_unnorm, _, _ = \
                rebin_data(cspec.freq, cspec.unnorm_power, df,
                           method=method, dx=cspec.df)

            bin_cs.unnorm_power = binpower_unnorm

        if hasattr(cspec, 'cs_all'):
            cs_all = []
            for c in cspec.cs_all:
                cs_all.append(c.rebin(df=df, f=f, method=method))
            bin_cs.cs_all = cs_all
        if hasattr(cspec, 'pds1'):
            bin_cs.pds1 = cspec.pds1.rebin(df=df, f=f, method=method)
        if hasattr(cspec, 'pds2'):
            bin_cs.pds2 = cspec.pds2.rebin(df=df, f=f, method=method)

        try:
            bin_cs.nphots2 = cspec.nphots2
        except AttributeError:
            if cspec.type == 'powerspectrum':
                pass
            else:
                raise AttributeError(
                    'Spectrum has no attribute named nphots2.')

        bin_cs.m = np.rint(step_size * cspec.m)

        return bin_cs

# %%
import copy
times = np.arange(10000000)
counts = np.random.rand(10000000)*100

lc1 = Lightcurve(times, counts, dt=1.0, skip_checks=True)
lc2 = Lightcurve(times, counts[::-1], dt=1.0, skip_checks=True)

cspec = Crossspectrum(lc1, lc2)

# %lprun -f rebin_data rebin(cspec, df=2.0)

del times, counts, lc1, lc2, cspec
# Out:
# Timer unit: 1e-06 s
#
# Total time: 2.63773 s
# File: <ipython-input-3-7798820b31f4>
# Function: rebin_data at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def rebin_data(x, y, dx_new, yerr=None, method='sum', dx=None):
#      2         2          7.0      3.5      0.0      y = np.asarray(y)
#      3         2       8958.0   4479.0      0.3      yerr = np.asarray(apply_function_if_none(yerr, y, np.zeros_like))
#      4
#      5         2      12289.0   6144.5      0.5      dx_old = apply_function_if_none(dx, np.diff(x), np.median)
#      6
#      7         2          6.0      3.0      0.0      if dx_new < dx_old:
#      8                                                   raise ValueError("New frequency resolution must be larger than "
#      9                                                                    "old frequency resolution.")
#     10
#     11         2          3.0      1.5      0.0      step_size = dx_new / dx_old
#     12
#     13         2          2.0      1.0      0.0      output = []
#     14         2          2.0      1.0      0.0      outputerr = []
#     15         4         31.0      7.8      0.0      for i in np.arange(0, y.shape[0], step_size):
#     16         2          0.0      0.0      0.0          total = 0
#     17         2          1.0      0.5      0.0          totalerr = 0
#     18
#     19         2          4.0      2.0      0.0          int_i = int(i)
#     20         2          3.0      1.5      0.0          prev_frac = int_i + 1 - i
#     21         2          2.0      1.0      0.0          prev_bin = int_i
#     22         2         40.0     20.0      0.0          total += prev_frac * y[prev_bin]
#     23         2         10.0      5.0      0.0          totalerr += prev_frac * (yerr[prev_bin] ** 2)
#     24
#     25         2          4.0      2.0      0.0          if i + step_size < len(x):
#     26                                                       # Fractional part of next bin:
#     27                                                       next_frac = i + step_size - int(i + step_size)
#     28                                                       next_bin = int(i + step_size)
#     29                                                       total += next_frac * y[next_bin]
#     30                                                       totalerr += next_frac * (yerr[next_bin] ** 2)
#     31
#     32         2    1319983.0 659991.5     50.0          total += sum(y[int(i + 1):int(i + step_size)])
#     33         2    1296242.0 648121.0     49.1          totalerr += sum(yerr[int(i + 1):int(step_size)] ** 2)
#     34         2          7.0      3.5      0.0          output.append(total)
#     35         2         30.0     15.0      0.0          outputerr.append(np.sqrt(totalerr))
#     36
#     37         2         23.0     11.5      0.0      output = np.asarray(output)
#     38         2          6.0      3.0      0.0      outputerr = np.asarray(outputerr)
#     39
#     40         2          2.0      1.0      0.0      if method in ['mean', 'avg', 'average', 'arithmetic mean']:
#     41         2         17.0      8.5      0.0          ybin = output / np.float(step_size)
#     42         2         10.0      5.0      0.0          ybinerr = outputerr / np.sqrt(np.float(step_size))
#     43
#     44                                               elif method == "sum":
#     45                                                   ybin = output
#     46                                                   ybinerr = outputerr
#     47
#     48                                               else:
#     49                                                   raise ValueError("Method for summing or averaging not recognized. "
#     50                                                                    "Please enter either 'sum' or 'mean'.")
#     51
#     52         2          6.0      3.0      0.0      tseg = x[-1] - x[0] + dx_old
#     53
#     54         2          8.0      4.0      0.0      if (tseg / dx_new % 1) > 0:
#     55         2          4.0      2.0      0.0          ybin = ybin[:-1]
#     56         2          1.0      0.5      0.0          ybinerr = ybinerr[:-1]
#     57
#     58         2          2.0      1.0      0.0      new_x0 = (x[0] - (0.5 * dx_old)) + (0.5 * dx_new)
#     59         2         24.0     12.0      0.0      xbin = np.arange(ybin.shape[0]) * dx_new + new_x0
#     60
#     61         2          2.0      1.0      0.0      return xbin, ybin, ybinerr, step_size

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## rms_error

# %%
import scipy.stats
def _rms_error1(pspec, powers):
    nphots = pspec.nphots
    p_err = scipy.stats.chi2(2.0 * pspec.m).var() * powers / pspec.m / nphots

    rms = np.sum(powers) / nphots
    pow = np.sqrt(rms)

    drms_dp = 1 / (2 * pow)

    sq_sum_err = np.sqrt(np.sum(p_err**2))
    delta_rms = sq_sum_err * drms_dp
    return delta_rms

# %%
def compute_rms(pspec, min_freq, max_freq, white_noise_offset=0.):
    minind = pspec.freq.searchsorted(min_freq)
    maxind = pspec.freq.searchsorted(max_freq)
    powers = pspec.power[minind:maxind]
    nphots = pspec.nphots

    if pspec.norm.lower() == 'leahy':
        powers_leahy = powers.copy()
    elif pspec.norm.lower() == "frac":
        powers_leahy = \
            pspec.unnorm_power[minind:maxind].real * 2 / nphots
    else:
        raise TypeError("Normalization not recognized!")

    rms = np.sqrt(np.sum(powers_leahy - white_noise_offset) / nphots)
    rms_err = _rms_error1(pspec, powers_leahy)

    return rms, rms_err

# %%
times = np.arange(10000000)
counts = np.random.rand(10000000)*100

lc = Lightcurve(times, counts, dt=1.0, skip_checks=True)
pspec = Powerspectrum(lc, norm='leahy')

# %lprun -f _rms_error1 compute_rms(pspec, min_freq=0.001, max_freq=0.499)

del times, counts, lc, pspec
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.023109 s
# File: <ipython-input-6-307575921b57>
# Function: _rms_error1 at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2                                           def _rms_error1(pspec, powers):
#      3         1          2.0      2.0      0.0      nphots = pspec.nphots
#      4         1      13076.0  13076.0     56.6      p_err = scipy.stats.chi2(2.0 * pspec.m).var() * powers / pspec.m / nphots
#      5
#      6         1       2065.0   2065.0      8.9      rms = np.sum(powers) / nphots
#      7         1          7.0      7.0      0.0      pow = np.sqrt(rms)
#      8
#      9         1          3.0      3.0      0.0      drms_dp = 1 / (2 * pow)
#     10
#     11         1       7954.0   7954.0     34.4      sq_sum_err = np.sqrt(np.sum(p_err**2))
#     12         1          1.0      1.0      0.0      delta_rms = sq_sum_err * drms_dp
#     13         1          1.0      1.0      0.0      return delta_rms

# %% [markdown]
# $\;\;\;\;\;\;$

# %% [markdown]
# ## gti_border_bins

# %%
def gti_border_bins(gtis, time, dt=None, epsilon=0.001):
    if dt is None:
        dt = np.median(np.diff(time))

    epsilon_times_dt = epsilon * dt
    spectrum_start_bins = np.array([], dtype=np.long)
    spectrum_stop_bins = np.array([], dtype=np.long)
    for g in gtis:
        good = (time - dt / 2 >= g[0]) & (time + dt / 2 <= g[1])
        t_good = time[good]
        if len(t_good) == 0:
            continue
        startbin = np.argmin(np.abs(time - dt / 2 - g[0]))
        stopbin = np.searchsorted(time + dt / 2, g[1], 'right') + 1
        if stopbin > len(time):
            stopbin = len(time)

        if time[startbin] < (g[0] + dt / 2 - epsilon_times_dt):
            startbin += 1
        # Would be g[1] - dt/2, but stopbin is the end of an interval
        # so one has to add one bin
        if time[stopbin - 1] > (g[1] - dt / 2 + epsilon_times_dt):
            stopbin -= 1
        spectrum_start_bins = \
            np.append(spectrum_start_bins,
                      [startbin])
        spectrum_stop_bins = \
            np.append(spectrum_stop_bins,
                      [stopbin])
    assert len(spectrum_start_bins) > 0, \
        ("No GTIs are equal to or longer than chunk_length.")
    return spectrum_start_bins, spectrum_stop_bins

# %%
times = np.arange(10000000)
counts = np.random.rand(10000000)*100

lc = Lightcurve(times, counts, dt=1.0, skip_checks=True)

# %lprun -f gti_border_bins gti_border_bins(lc.gti, lc.time, lc.dt)

del times, counts, lc
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.124913 s
# File: <ipython-input-2-ae32d5e7cef5>
# Function: gti_border_bins at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def gti_border_bins(gtis, time, dt=None, epsilon=0.001):
#      2         1          1.0      1.0      0.0      if dt is None:
#      3                                                   dt = np.median(np.diff(time))
#      4
#      5         1          0.0      0.0      0.0      epsilon_times_dt = epsilon * dt
#      6         1          3.0      3.0      0.0      spectrum_start_bins = np.array([], dtype=np.long)
#      7         1          2.0      2.0      0.0      spectrum_stop_bins = np.array([], dtype=np.long)
#      8         2          8.0      4.0      0.0      for g in gtis:
#      9         1      44724.0  44724.0     35.8          good = (time - dt / 2 >= g[0]) & (time + dt / 2 <= g[1])
#     10         1      17851.0  17851.0     14.3          t_good = time[good]
#     11         1          4.0      4.0      0.0          if len(t_good) == 0:
#     12                                                       continue
#     13         1      45357.0  45357.0     36.3          startbin = np.argmin(np.abs(time - dt / 2 - g[0]))
#     14         1      16884.0  16884.0     13.5          stopbin = np.searchsorted(time + dt / 2, g[1], 'right') + 1
#     15         1          2.0      2.0      0.0          if stopbin > len(time):
#     16         1          1.0      1.0      0.0              stopbin = len(time)
#     17
#     18         1         17.0     17.0      0.0          if time[startbin] < (g[0] + dt / 2 - epsilon_times_dt):
#     19                                                       startbin += 1
#     20                                                   # Would be g[1] - dt/2, but stopbin is the end of an interval
#     21                                                   # so one has to add one bin
#     22         1          6.0      6.0      0.0          if time[stopbin - 1] > (g[1] - dt / 2 + epsilon_times_dt):
#     23                                                       stopbin -= 1
#     24         1          1.0      1.0      0.0          spectrum_start_bins = \
#     25         2         38.0     19.0      0.0              np.append(spectrum_start_bins,
#     26         1          1.0      1.0      0.0                        [startbin])
#     27         1          0.0      0.0      0.0          spectrum_stop_bins = \
#     28         2         11.0      5.5      0.0              np.append(spectrum_stop_bins,
#     29         1          0.0      0.0      0.0                        [stopbin])
#     30         1          1.0      1.0      0.0      assert len(spectrum_start_bins) > 0, \
#     31                                                   ("No GTIs are equal to or longer than chunk_length.")
#     32         1          1.0      1.0      0.0      return spectrum_start_bins, spectrum_stop_bins

# %% [markdown]
# $\;\;\;\;\;\;$
